# %%
import json
from typing import Optional, Literal
from contextvars import ContextVar

import dspy
from pydantic import BaseModel, Field, field_validator

additional_args = ContextVar('additional_args', default={})
# config
lm = dspy.LM('openai/gpt-4o', cache=False)
dspy.configure(lm=lm)


class Target(BaseModel):
    target_formula: str = Field(description='make sure it is a valid chemical formula')
    amount_var: dict[str, list[float]] = Field(description='the amount variable in the formula, e.g. AxBC, {x: [1, 2]}')
    element_var: dict[str, list[str]] = Field(description='the element variable in the formula')

class Reaction(BaseModel):
    precursors: list[str] = Field(description='ensure it is a valid chemical formula')
    additives: list[str]
    target: Target
    reaction_type: Literal['solid-state', 'sol-gel', 'co-precipitation', 'hydrothermal', 'flux', 'others']

    # @field_validator('precursors')
    # @classmethod
    # def validate_precusors(cls, v):
    #     if not v:
    #         raise ValueError('precursors should not be empty')
    #     return v
    

class QA(dspy.Signature):
    """extract all chmemical reactions consitituent from the text.
    Note: please only include those reactions in which precursors and target are explicitly mentioned in the text.
    Intermediate reaction should be extracted as well."""
    text: str = dspy.InputField(desc='a piece of text which may contains chemical reactions')
    reactions: Optional[list[Reaction]] = dspy.OutputField(desc='the reactions extracted from the text, return null if no reaction found')

class ExtractReactionWithType(dspy.Module):
    def __init__(self):
        self.predictor = dspy.ChainOfThought(signature=QA)

    def forward(self, text):
        prediction = self.predictor(text=text)
        return prediction

class ExtractReactionTandem(dspy.Module):
    def __init__(self):
        self.predictor = dspy.ChainOfThought(signature=QA)

    def forward(self, text):
        summary = chain.invoke({"text": text})
        prediction = self.predictor(text=summary)
        return prediction

from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
opt_v4 = """Extract detailed reaction information from the provided experimental description. For each reaction, structure the output as follows:  

1. **Overview of the Reaction:**
   - Identify the main target compound(s).
   - List the key precursor(s).  

2. **Detailed Reaction Steps:**
   - For each distinct reaction or synthesis process, specify:  
     - **Precursors**: List the starting materials.  
     - **Target Compounds**: Name the products formed in that step.  
     - **Experimental Procedure**: Describe the operations involved (e.g., mixing, milling, calcination) and include relevant conditions (e.g., temperature, duration).  
   - Highlight intermediate products and subsequent reactions involving them.  

3. **Final Processing Steps:**
   - Summarize operations for combining and processing intermediate products into final forms (e.g., granulation, pressing, sintering).  

Ensure clarity and organization by grouping steps logically and labeling each reaction or procedure distinctly. 
Additional Guidelines: 
Logical Grouping: Organize reactions sequentially or thematically, ensuring that all described reactions are included and distinctly labeled.
text:
{text}"""
chatmodel = ChatOpenAI(model='gpt-4o', temperature=0)
prompt = PromptTemplate.from_template(opt_v4)
chain = prompt | chatmodel | StrOutputParser()

# %%
doc = """Identify and extract all chemical reactions from the text. For each reaction:

Include reactions where precursors and target products are explicitly mentioned.
Ensure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.
Also extract intermediate reactions and label them as such."""
QA.__doc__ = doc

# %%
QA.__doc__ = "extract reactions from given text"

# %%
extractor = ExtractReactionWithType()
extractor.predictor.extended_signature
# Out:
# StringSignature(text -> reasoning, reactions
#     instructions='extract reactions from given text'
#     text = Field(annotation=str required=True json_schema_extra={'desc': 'a piece of text which may contains chemical reactions', '__dspy_field_type': 'input', 'prefix': 'Text:'})
#     reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#     reactions = Field(annotation=Union[list[Reaction], NoneType] required=True json_schema_extra={'desc': 'the reactions extracted from the text, return null if no reaction found', '__dspy_field_type': 'output', 'prefix': 'Reactions:'})
# )

# %%
from sisyphus.utils.helper_functions import load_from_curated_examples
from dspy.datasets.dataloader import DataLoader

dataset = load_from_curated_examples('curated_examples.json', ('text', 'reactions'), ('text',), Reaction)
splits = DataLoader().train_test_split(dataset, train_size=0.4, random_state=44)
train, dev = splits['train'], splits['test']

# %%
train
# Out:
# [Example({'text': '(1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x\u2009=\u20090.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (>\u200999%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x\u2009=\u20090.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x\u2009=\u20090.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.', 'reactions': [Reaction(precursors=['CaCO3', 'SrCO3', 'TiO2'], additives=[], target=Target(target_formula='Ca0.88Sr0.12TiO3', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['Bi2O3', 'Na2CO3', 'TiO2'], additives=[], target=Target(target_formula='Bi0.5Na0.5TiO3', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['Ca0.88Sr0.12TiO3', 'Bi0.5Na0.5TiO3'], additives=['PVA'], target=Target(target_formula='(1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3', amount_var={'x': [0.025, 0.05, 0.075, 0.1]}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.', 'reactions': [Reaction(precursors=['Bi2SrNa2Nb4O9', 'NaNbO3'], additives=[], target=Target(target_formula='Bi2SrNa2Nb4O15', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.', 'reactions': [Reaction(precursors=['Na4P2O7', 'MnCO3', 'NH4H2PO4'], additives=[], target=Target(target_formula='Na4Mn3(PO4)2(P2O7)', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['Na4P2O7', 'CoCO3·4H2O', 'NH4H2PO4'], additives=[], target=Target(target_formula='Na4Co3(PO4)2(P2O7)', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['Na4P2O7', 'Ni(NO3)2·6H2O', 'NH4H2PO4'], additives=[], target=Target(target_formula='Na4Ni3(PO4)2(P2O7)', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.', 'reactions': [Reaction(precursors=['Bi(NO3)3', 'KCl'], additives=[], target=Target(target_formula='BiOCl', amount_var={}, element_var={}), reaction_type='co-precipitation'), Reaction(precursors=['BiOCl', 'Ca(NO3)2'], additives=[], target=Target(target_formula='CaBiO2Cl', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).', 'reactions': [Reaction(precursors=['LiH2PO4', 'Fe2O3', 'NH4H2PO4'], additives=[], target=Target(target_formula='LiFeP2O7', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000\u202f°C for 5\u202fh in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000\u202f°C for 5\u202fh in air.', 'reactions': [Reaction(precursors=['Ba(NO3)2', 'Ce(NO3)3⋅6H2O', 'In(NO3)3⋅4.5H2O', 'Y(NO3)3⋅6H2O', 'Ta2O5'], additives=['citric acid'], target=Target(target_formula='BaCe0.7In0.15Ta0.05Y0.1O3-δ', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'})]

# %%
dev
# Out:
# [Example({'text': 'Perovskite nanosheets were prepared by delaminating layered perovskites according to previously described procedures. The starting material KCa2Nb3O10, prepared by a solid-state reaction, was converted into a protonic form, HCa2Nb3O10 1.5H2O, in HNO3 solution. A colloidal suspension of Ca2Nb3O10 nanosheets was synthesized by delaminating HCa2Nb3O10 1.5H2O, with tetrabutylammonium hydroxide solution (TBAOH). Sr2Nb3O10, Ca2Ta3O10, and Sr2Ta3O10 nanosheets were also synthesized by delaminating layered perovskites (KSr2Nb3O10, KCa2Ta3O10, and KSr2Ta3O10).', 'reactions': [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Target(target_formula='HCa2Nb3O10 1.5H2O', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['HCa2Nb3O10 1.5H2O'], additives=['TBAOH'], target=Target(target_formula='Ca2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Nb3O10'], additives=[], target=Target(target_formula='Sr2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KCa2Ta3O10'], additives=[], target=Target(target_formula='Ca2Ta3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Ta3O10'], additives=[], target=Target(target_formula='Sr2Ta3O10', amount_var={}, element_var={}), reaction_type='others')]}) (input_keys={'text'}),
#  Example({'text': 'Strontium titanate doped with rhodium species (SrTiO3:Rh) was prepared by solid state reaction. A mixture of SrCO3, TiO2 and Rh2O3 (Sr:Ti:Rh = 1:0.99:0.01 to form the ideal formula of SrTi0.99Rh0.01O3-δ) was calcined in air at 873 K for 2 h and subsequently at 1273 K for 10 h. A Pt cocatalyst was loaded onto SrTiO3:Rh by impregnation using H2PtCl6 6H2O and subsequent heating under a H2 flow at 573 K for 2 h. In the case of a Ru cocatalyst, Ru species were loaded on SrTiO3:Rh by means of a photodeposition method using RuCl3 nH2O as a Ru source, according to the method reported previously.', 'reactions': [Reaction(precursors=['SrCO3', 'TiO2', 'Rh2O3'], additives=[], target=Target(target_formula='SrTi0.99Rh0.01O3-δ', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'Polycrystalline samples of ACu3Sn4O12 (A = Ca2+, Sr2+, and Pb2+) were prepared under high-temperature and high-pressure conditions. CaCO3, SrCO3, PbO, CuO, and SnO2 were used as starting powder materials for the synthesis. Calcined samples of CaCu3Sn4O12 and SrCu3Sn4O12 were made by heating the mixture of raw materials at 1000 °C for 20 h in air. They were ground, packed into gold capsules, and then pressed under 6 GPa at 1000 °C for 30 min with a cubic-anvil-type high-pressure apparatus. The mixture of PbO, CuO, and SnO2 for the synthesis of PbCu3Sn4O12 was treated under the same high-temperature and high-pressure condition used in the synthesis of CaCu3Sn4O12 and SrCu3Sn4O12.', 'reactions': [Reaction(precursors=['CaCO3', 'CuO', 'SnO2'], additives=[], target=Target(target_formula='CaCu3Sn4O12', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['SrCO3', 'CuO', 'SnO2'], additives=[], target=Target(target_formula='SrCu3Sn4O12', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['PbO', 'CuO', 'SnO2'], additives=[], target=Target(target_formula='PbCu3Sn4O12', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'The particles of SrTiO3:Rh(2%) were prepared via the water-based hetero-chelate method (WH-method), which was recently developed by our group, using a stable titania sol as a precursor. The aqueous titania sol (AA-sol) was prepared by mixing TIPT, an aqueous solution of acac, and an aqueous solution of AcOH. The AA-sol was mixed with an aqueous solution containing both Sr(OAc)2 (1.08 mol L-1) and lactic acid (2.16 mol L-1) and an aqueous solution of RhCl3 (0.24 mol L-1) at a ratio of Sr:Ti:Rh = 1.02:0.98:0.02, and stirred for 1 hour at room temperature, yielding an orange transparent sol. To the sol was added an acrylic emulsion and it was stirred for 15 minutes at room temperature, then dried at 80 °C for 3 hours, and finally calcined at 1000 °C for 10 hours, yielding SrTiO3:Rh (Rh: 2%) powdered samples (these samples are denoted as WH-particles). For comparison, SrTiO3:Rh(2%) particles were also prepared via the solid state reaction method (SS-method) using TiO2, SrCO3 and Rh2O3 as raw materials, and calcination at 1000 °C for 10 hours (these samples will be denoted by SS-particles) followed.', 'reactions': [Reaction(precursors=['TiO2', 'SrCO3', 'Rh2O3'], additives=[], target=Target(target_formula='SrTiO3:Rh', amount_var={}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['TIPT', 'Sr(OAc)2', 'RhCl3'], additives=['lactic acid', 'acrylic emulsion'], target=Target(target_formula='SrTiO3:Rh', amount_var={}, element_var={}), reaction_type='others')]}) (input_keys={'text'}),
#  Example({'text': 'Nonetheless, the molten salt flux assistance has room for optimization and provides control over the synthesized material. The effect of controlling the flux parameters (reactant to flux molar ratio, temperature, and time) on the hydrogen evolution photocatalytic activity of SnNb2O6 was investigated as a means to control the surface properties. They started from SnO and Nb2O5 with excess SnCl2, and the molar ratio of reactant to flux was varied between 1:1 and 1:14. The crystal morphology was tuned by increasing the flux to reactant molar ratio, affording well-defined particles with non-aggregated surfaces. The XRD patterns and SEM analyses confirmed a 2D anisotropic growth along the (bc) plane, providing a plate-like morphology as the flux ratio increased. Fig. 6 shows SEM images of SnNb2O6 synthesized by the molten salt flux-assisted method and by solid-state synthesis.', 'reactions': [Reaction(precursors=['SnO', 'Nb2O5'], additives=['SnCl2'], target=Target(target_formula='SnNb2O6', amount_var={}, element_var={}), reaction_type='flux')]}) (input_keys={'text'}),
#  Example({'text': 'The Sr1−xCexCo0.2Fe0.8O3−δ (x = 0.0, 0.10, 0.15 and 0.20) and La0.6Sr0.4Co0.2Fe0.8O3−δ (LSCF6428) samples were synthesized by the EDTA-citrate complexing method. Stoichiometric amounts of metal nitrate precursors Sr(NO3)2 (Alfa Aesar), Co(NO3)2·6H2O (Acros Organics), Fe(NO3)3·6H2O (Sigma Aldrich), and Ce(NO3)3·6H2O (Fisher Scientific) or La(NO3)3·6H2O (Sigma Aldrich) were dissolved in distilled water and EDTA (Ethylenediaminetetraacetic acid) was added to the solution while stirring continuously. A solution of ammonium hydroxide (NH4OH) was used to control the pH at 6. At a pH of 6 and a temperature of 60 °C, citric acid was added to the solution. The mole ratio of metal ions to EDTA and citric acid was 1:1:1.5. The mixed solution was then heated to 90 °C while stirring until a brown gel was formed. The gel was dried overnight in an oven at 150 °C, followed by grinding the formed precursors. The ground powder was calcined in air at 1100 °C for 5 h to allow the cubic perovskite phase to form. The NiO–YSZ was synthesized using a conventional solid-state method, for which the details are presented in our previous publication.', 'reactions': [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O', 'Ce(NO3)3·6H2O'], additives=['EDTA', 'citric acid', 'NH4OH'], target=Target(target_formula='Sr1−xCexCo0.2Fe0.8O3−δ', amount_var={'x': [0.0, 0.1, 0.15, 0.2]}, element_var={}), reaction_type='others'), Reaction(precursors=['La(NO3)3·6H2O', 'Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'], additives=['EDTA', 'citric acid', 'NH4OH'], target=Target(target_formula='La0.6Sr0.4Co0.2Fe0.8O3−δ', amount_var={}, element_var={}), reaction_type='others')]}) (input_keys={'text'}),
#  Example({'text': 'We used sources of thallium with a composition TlxBa2Ca2Cu3Oz (x=1.0–1.8) and a weight of 0.5 or 3 g. They were prepared by mixing stoichiometric amounts of Tl2O3 and the mixed oxides BaCuO2 and Ca2CuO3 with the composition “Ba2Ca2Cu3O7” (prepared by solid state reaction in flowing oxygen at 900 °C and 24 h from BaO2, CuO and pre-fired CaO).', 'reactions': [Reaction(precursors=['Tl2O3', 'BaCuO2', 'Ca2CuO3', 'Ba2Ca2Cu3O7'], additives=[], target=Target(target_formula='TlxBa2Ca2Cu3Oz', amount_var={'x': [1.0, 1.8]}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['BaO2', 'CuO', 'CaO'], additives=[], target=Target(target_formula='Ba2Ca2Cu3O7', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'Single crystals of Cd4YbO(BO3)3 were grown through high-temperature solid state reactions. A mixture of CdCO3 (8.0 mmol), H3BO3 (6.0 mmol) and Yb2O3 (1.0 mmol) in the molar ratio of 8:6:1 was ground and loaded into a platinum crucible. The synthesis was performed in four steps. First, the mixture was heated at 500 °C for one day in order to decompose H3BO3 and CdCO3. Second, the resulting mixture was further heated for one day at 1200 °C until a transparent and clear melt was formed. Third, the melt was allowed to cool slowly (3 °C h-1) to the final crystallization temperature (1100 °C). Finally, the obtained mixture was quenched to room temperature. Colorless, transparent crystals were obtained for structure determination. After proper structural analysis, pure powder samples of Cd4YbO(BO3)3 were obtained in quantitative yield through the solid-state reactions from a stoichiometric mixture of CdCO3, H3BO3 and Yb2O3 at 950 °C for 5 days.', 'reactions': [Reaction(precursors=['CdCO3', 'H3BO3', 'Yb2O3'], additives=[], target=Target(target_formula='Cd4YbO(BO3)3', amount_var={}, element_var={}), reaction_type='solid-state')]}) (input_keys={'text'}),
#  Example({'text': 'Single crystals of TbBaMn2O6 were obtained by floating zone (FZ) method. The synthesis of the powder sample requires several complex processes as described in Ref. [2]. Starting materials Tb4O7, MnCO3 and BaCO3 were thoroughly ground, pressed into pellets and calcined in an Ar flow at 1300 °C for 24 h, which yielded the A-site ordered oxygen-deficient perovskite TbBaMn2O6−y with a large amount (y∼1) of oxygen vacancy in the TbO layer. By floating-zone method using sintered TbBaMn2O6−y (y∼1), single crystals were grown at a crystallization rate of 15 mm/h under Ar gas flow. Then, obtained crystals were annealed under flowing O2 at 500 °C for 48 h, by which crystals were fully oxidized to TbBaMn2O6 (y→0) without a solid solution of Tb/Ba at the A-sites.', 'reactions': [Reaction(precursors=['Tb4O7', 'MnCO3', 'BaCO3'], additives=[], target=Target(target_formula='TbBaMn2O6−y', amount_var={'y': [1.0]}, element_var={}), reaction_type='solid-state'), Reaction(precursors=['TbBaMn2O6−y'], additives=[], target=Target(target_formula='TbBaMn2O6', amount_var={}, element_var={}), reaction_type='others')]}) (input_keys={'text'})]

# %%
train[0].inputs().keys()
# Out:
# ['text']

# %%
class Match(dspy.Signature):
    """whether the extract reactions match the gold reactions"""
    gold = dspy.InputField(desc='the gold reactions which should be extracted')
    extracted = dspy.InputField(desc='the extracted reactions')
    answer: Literal['yes', 'no'] = dspy.OutputField(desc='Does the extracted reactions match the gold reactions? Tolerate some minor differences')

def metric(gold, pred, trace=None):
    def render_reactions(reactions):
        repr_reactions = []
        for reaction in reactions:
            precursors = reaction.precursors
            target = reaction.target.target_formula
            target_amount_var = reaction.target.amount_var
            reprsentation = f"precursors: {','.join(precursors)}, target: {target}, target amount variable: {target_amount_var}"
            repr_reactions.append(reprsentation)
        return '\n'.join(repr_reactions)
    gold_reactions = render_reactions(gold.reactions)
    extracted_reactions = render_reactions(pred.reactions)
    answer = dspy.ChainOfThought(Match)(gold=gold_reactions, extracted=extracted_reactions).answer
    return True if answer == 'yes' else False

# %%
optimizer = dspy.BootstrapFewShot(metric=metric, max_bootstrapped_demos=6)
uncompiled_direct = ExtractReactionWithType()
uncompiled_tandem = ExtractReactionTandem()

# %%
compiled_direct = optimizer.compile(uncompiled_direct, trainset=train)
# Out:
# 100%|██████████| 6/6 [00:37<00:00,  6.26s/it]
# Bootstrapped 5 full traces after 5 examples for up to 1 rounds, amounting to 6 attempts.

# %%
vanilla = dspy.Predict(QA)
compiled_vanilla = optimizer.compile(vanilla, trainset=train)
# Out:
# 100%|██████████| 6/6 [00:30<00:00,  5.11s/it]
# Bootstrapped 4 full traces after 5 examples for up to 1 rounds, amounting to 6 attempts.

# %%
import sisyphus.patch.dspy_patch
file_name = 'compiled_direct_with_element_var_version_2'
compiled_direct.save('compiled_direct_with_element_var_version_2')

# %%
compiled_tandem = optimizer.compile(uncompiled_tandem, trainset=train)
# Out:
# 100%|██████████| 6/6 [02:31<00:00, 25.30s/it]
# Bootstrapped 3 full traces after 5 examples for up to 1 rounds, amounting to 6 attempts.

# %%
from dspy.evaluate import Evaluate

devset = dev
evaluate = Evaluate(devset=devset, metric=metric, num_threads=10, display_progress=True, display_table=True)
# evaluate(uncompiled_direct)

# %%
evaluate(extractor, metric=metric, num_threads=10, display_progress=True, display_table=True, devset=train)
# Out:
# Average Metric: 4.00 / 6 (66.7%): 100%|██████████| 6/6 [00:16<00:00,  2.80s/it]
# 2024/12/18 16:34:24 INFO dspy.evaluate.evaluate: Average Metric: 4 / 6 (66.7%)
#                                                                     text  \
# 0  (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to a...
# 1  Three interesting papers published during this review period demon...
# 2  The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obta...
# 3  CaBiO2Cl samples were prepared by a two-step process. All chemical...
# 4  Polycrystalline LiFeP2O7 was synthesized by solid-state methods. S...
# 5  The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by com...
#
#                                                        example_reactions  \
# 0  [Reaction(precursors=['CaCO3', 'SrCO3', 'TiO2'], additives=[], tar...
# 1  [precursors=['Bi2SrNa2Nb4O9', 'NaNbO3'] additives=[] target=Target...
# 2  [precursors=['Na4P2O7', 'MnCO3', 'NH4H2PO4'] additives=[] target=T...
# 3  [precursors=['Bi(NO3)3', 'KCl'] additives=[] target=Target(target_...
# 4  [precursors=['LiH2PO4', 'Fe2O3', 'NH4H2PO4'] additives=[] target=T...
# 5  [precursors=['Ba(NO3)2', 'Ce(NO3)3⋅6H2O', 'In(NO3)3⋅4.5H2O', 'Y(NO...
#
#                                                                reasoning  \
# 0  The text describes the preparation of (1−x)(Ca0.88Sr0.12)TiO3–x(Bi...
# 1  The text describes various studies involving chemical analysis tec...
# 2  The text describes a solid-state reaction process to synthesize ne...
# 3  The text describes two chemical reactions. The first reaction invo...
# 4  The text describes the synthesis of polycrystalline LiFeP2O7 using...
# 5  The text describes the preparation of two different powders: BaCe0...
#
#                                                           pred_reactions  \
# 0  [precursors=['CaCO3', 'SrCO3', 'Bi2O3', 'Na2CO3', 'TiO2'] additive...
# 1  [precursors=['Bi2SrNa2Nb4O9', 'NaNbO3'] additives=[] target=Target...
# 2  [Reaction(precursors=['Na4P2O7', 'MnCO3', 'NH4H2PO4'], additives=[...
# 3  [precursors=['Bi(NO3)3', 'KCl'] additives=['H2O'] target=Target(ta...
# 4  [precursors=['LiH2PO4', 'Fe2O3', 'NH4H2PO4'] additives=[] target=T...
# 5  [precursors=['Ba(NO3)2', 'Ce(NO3)3⋅6H2O', 'In(NO3)3⋅4.5H2O', 'Y(NO...
#
#       metric
# 0
# 1  ✔️ [True]
# 2  ✔️ [True]
# 3  ✔️ [True]
# 4  ✔️ [True]
# 5
# 66.67

# %%
extractor(text=train[0].text)
# Out:
# Prediction(
#     reasoning='The text describes the preparation of (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 ceramics using a conventional solid-state reaction method. The precursors used are CaCO3, SrCO3, Bi2O3, Na2CO3, and TiO2. The process involves mixing these starting materials, milling, drying, calcining, re-milling, granulating with PVA, pressing into cylinders, and sintering. The reaction type is clearly stated as a solid-state reaction. The target formula is (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3, with x being a variable amount (0.025, 0.050, 0.075, 0.10). There are no element variables in the target formula.',
#     reactions=[Reaction(precursors=['CaCO3', 'SrCO3', 'Bi2O3', 'Na2CO3', 'TiO2'], additives=['ZrO2', 'H2O', 'PVA'], target=Target(target_formula='(1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3', amount_var={'x': [0.025, 0.05, 0.075, 0.1]}, element_var={}), reaction_type='solid-state')]
# )

# %%
extractor(text=train[5].text)
# Out:
# Prediction(
#     reasoning='The text describes the preparation of two different powders: BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) and BaCe0.7Y0.3O3-δ (BCY). The preparation of BCITY involves a combination of solid-state reaction and the Pechini method, while BCY is prepared solely by the Pechini method. The precursors for BCITY include Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, Y(NO3)3⋅6H2O, and Ta2O5, with citric acid as an additive. The process involves dissolving these precursors in water, adjusting the pH, and heating to form a gel, which is then ignited and calcined. The BCY preparation involves similar steps but without the inclusion of In and Ta precursors. The reactions can be categorized as "others" due to the combination of methods used.',
#     reactions=[Reaction(precursors=['Ba(NO3)2', 'Ce(NO3)3⋅6H2O', 'In(NO3)3⋅4.5H2O', 'Y(NO3)3⋅6H2O', 'Ta2O5'], additives=['citric acid', 'ammonia water'], target=Target(target_formula='BaCe0.7In0.15Ta0.05Y0.1O3-δ', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['Ba(NO3)2', 'Ce(NO3)3⋅6H2O', 'Y(NO3)3⋅6H2O'], additives=['citric acid', 'ammonia water'], target=Target(target_formula='BaCe0.7Y0.3O3-δ', amount_var={}, element_var={}), reaction_type='others')]
# )

# %%
evaluate(extractor, metric=metric, num_threads=10, display_progress=True, display_table=True, devset=dev)
# Out:
# Average Metric: 8.00 / 9 (88.9%): 100%|██████████| 9/9 [00:18<00:00,  2.08s/it]
# 2024/12/18 17:20:38 INFO dspy.evaluate.evaluate: Average Metric: 8 / 9 (88.9%)
#                                                                     text  \
# 0  Perovskite nanosheets were prepared by delaminating layered perovs...
# 1  Strontium titanate doped with rhodium species (SrTiO3:Rh) was prep...
# 2  Polycrystalline samples of ACu3Sn4O12 (A = Ca2+, Sr2+, and Pb2+) w...
# 3  The particles of SrTiO3:Rh(2%) were prepared via the water-based h...
# 4  Nonetheless, the molten salt flux assistance has room for optimiza...
# 5  The Sr1−xCexCo0.2Fe0.8O3−δ (x = 0.0, 0.10, 0.15 and 0.20) and La0....
# 6  We used sources of thallium with a composition TlxBa2Ca2Cu3Oz (x=1...
# 7  Single crystals of Cd4YbO(BO3)3 were grown through high-temperatur...
# 8  Single crystals of TbBaMn2O6 were obtained by floating zone (FZ) m...
#
#                                                        example_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Ta...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [precursors=['CaCO3', 'CuO', 'SnO2'] additives=[] target=Target(ta...
# 3  [precursors=['TiO2', 'SrCO3', 'Rh2O3'] additives=[] target=Target(...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['Tl2O3', 'BaCuO2', 'Ca2CuO3', 'Ba2Ca2Cu3O7'] additive...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=[] target=Target...
#
#                                                                reasoning  \
# 0  The text describes the preparation of perovskite nanosheets throug...
# 1  The text describes the preparation of strontium titanate doped wit...
# 2  The text describes the synthesis of polycrystalline samples of ACu...
# 3  The text describes two methods for preparing SrTiO3:Rh(2%) particl...
# 4  The text describes a chemical reaction process involving the synth...
# 5  The text describes the synthesis of two different materials: Sr1−x...
# 6  The text describes a chemical reaction process involving the prepa...
# 7  The text describes the synthesis of single crystals of Cd4YbO(BO3)...
# 8  The text describes the synthesis of TbBaMn2O6 through a series of ...
#
#                                                           pred_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Ta...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [Reaction(precursors=['CaCO3', 'CuO', 'SnO2'], additives=[], targe...
# 3  [precursors=['TIPT', 'acac', 'AcOH', 'Sr(OAc)2', 'RhCl3'] additive...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['BaO2', 'CuO', 'CaO'] additives=[] target=Target(targ...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=['Ar'] target=Ta...
#
#       metric
# 0  ✔️ [True]
# 1  ✔️ [True]
# 2  ✔️ [True]
# 3
# 4  ✔️ [True]
# 5  ✔️ [True]
# 6  ✔️ [True]
# 7  ✔️ [True]
# 8  ✔️ [True]
# 88.89

# %%
extractor(text=dev[3].text)
# Out:
# Prediction(
#     reasoning='The text describes two methods for preparing SrTiO3:Rh(2%) particles. The first method is the water-based hetero-chelate method (WH-method), which involves using a titania sol as a precursor and mixing it with solutions of Sr(OAc)2, lactic acid, and RhCl3. The process includes stirring, drying, and calcination. The second method is the solid-state reaction method (SS-method), which uses TiO2, SrCO3, and Rh2O3 as raw materials, followed by calcination. Both methods result in the formation of SrTiO3:Rh(2%) particles. The reactions can be categorized based on the precursors, additives, and the target compound.',
#     reactions=[Reaction(precursors=['TIPT', 'Sr(OAc)2', 'RhCl3'], additives=['acac', 'AcOH', 'lactic acid', 'acrylic emulsion'], target=Target(target_formula='SrTiO3:Rh', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['TiO2', 'SrCO3', 'Rh2O3'], additives=[], target=Target(target_formula='SrTiO3:Rh', amount_var={}, element_var={}), reaction_type='solid-state')]
# )

# %%
evaluate(vanilla)
# Out:
# Average Metric: 6.00 / 9 (66.7%): 100%|██████████| 9/9 [00:09<00:00,  1.00s/it]
# 2024/12/13 14:50:03 INFO dspy.evaluate.evaluate: Average Metric: 6 / 9 (66.7%)
#                                                                     text  \
# 0  Perovskite nanosheets were prepared by delaminating layered perovs...
# 1  Strontium titanate doped with rhodium species (SrTiO3:Rh) was prep...
# 2  Polycrystalline samples of ACu3Sn4O12 (A = Ca2+, Sr2+, and Pb2+) w...
# 3  The particles of SrTiO3:Rh(2%) were prepared via the water-based h...
# 4  Nonetheless, the molten salt flux assistance has room for optimiza...
# 5  The Sr1−xCexCo0.2Fe0.8O3−δ (x = 0.0, 0.10, 0.15 and 0.20) and La0....
# 6  We used sources of thallium with a composition TlxBa2Ca2Cu3Oz (x=1...
# 7  Single crystals of Cd4YbO(BO3)3 were grown through high-temperatur...
# 8  Single crystals of TbBaMn2O6 were obtained by floating zone (FZ) m...
#
#                                                        example_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Ta...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [precursors=['CaCO3', 'CuO', 'SnO2'] additives=[] target=Target(ta...
# 3  [precursors=['TiO2', 'SrCO3', 'Rh2O3'] additives=[] target=Target(...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['Tl2O3', 'BaCuO2', 'Ca2CuO3', 'Ba2Ca2Cu3O7'] additive...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=[] target=Target...
#
#                                                           pred_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Ta...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [Reaction(precursors=['CaCO3', 'CuO', 'SnO2'], additives=[], targe...
# 3  [precursors=['TIPT', 'acac', 'AcOH', 'Sr(OAc)2', 'RhCl3'] additive...
# 4  [precursors=['SnO', 'Nb2O5', 'SnCl2'] additives=[] target=Target(t...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['BaO2', 'CuO', 'CaO'] additives=[] target=Target(targ...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=['Ar'] target=Ta...
#
#       metric
# 0  ✔️ [True]
# 1
# 2  ✔️ [True]
# 3  ✔️ [True]
# 4
# 5
# 6  ✔️ [True]
# 7  ✔️ [True]
# 8  ✔️ [True]
# 66.67

# %%
evaluate(compiled_vanilla)
# Out:
# Average Metric: 8.00 / 9 (88.9%): 100%|██████████| 9/9 [00:06<00:00,  1.34it/s]
# 2024/12/13 14:50:22 INFO dspy.evaluate.evaluate: Average Metric: 8 / 9 (88.9%)
#                                                                     text  \
# 0  Perovskite nanosheets were prepared by delaminating layered perovs...
# 1  Strontium titanate doped with rhodium species (SrTiO3:Rh) was prep...
# 2  Polycrystalline samples of ACu3Sn4O12 (A = Ca2+, Sr2+, and Pb2+) w...
# 3  The particles of SrTiO3:Rh(2%) were prepared via the water-based h...
# 4  Nonetheless, the molten salt flux assistance has room for optimiza...
# 5  The Sr1−xCexCo0.2Fe0.8O3−δ (x = 0.0, 0.10, 0.15 and 0.20) and La0....
# 6  We used sources of thallium with a composition TlxBa2Ca2Cu3Oz (x=1...
# 7  Single crystals of Cd4YbO(BO3)3 were grown through high-temperatur...
# 8  Single crystals of TbBaMn2O6 were obtained by floating zone (FZ) m...
#
#                                                        example_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Ta...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [precursors=['CaCO3', 'CuO', 'SnO2'] additives=[] target=Target(ta...
# 3  [precursors=['TiO2', 'SrCO3', 'Rh2O3'] additives=[] target=Target(...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['Tl2O3', 'BaCuO2', 'Ca2CuO3', 'Ba2Ca2Cu3O7'] additive...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=[] target=Target...
#
#                                                           pred_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=[], target=Target(t...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [precursors=['CaCO3', 'CuO', 'SnO2'] additives=[] target=Target(ta...
# 3  [precursors=['TIPT', 'Sr(OAc)2', 'RhCl3'] additives=['acac', 'AcOH...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['BaO2', 'CuO', 'CaO'] additives=[] target=Target(targ...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=[] target=Target...
#
#       metric
# 0  ✔️ [True]
# 1  ✔️ [True]
# 2  ✔️ [True]
# 3  ✔️ [True]
# 4  ✔️ [True]
# 5  ✔️ [True]
# 6  ✔️ [True]
# 7  ✔️ [True]
# 8
# 88.89

# %%
evaluate(compiled_direct, display_progress=True, display_table=True)
# Out:
# Average Metric: 7.00 / 9 (77.8%): 100%|██████████| 9/9 [00:21<00:00,  2.38s/it]
# 2024/12/13 12:33:37 INFO dspy.evaluate.evaluate: Average Metric: 7 / 9 (77.8%)
#                                                                     text  \
# 0  Perovskite nanosheets were prepared by delaminating layered perovs...
# 1  Strontium titanate doped with rhodium species (SrTiO3:Rh) was prep...
# 2  Polycrystalline samples of ACu3Sn4O12 (A = Ca2+, Sr2+, and Pb2+) w...
# 3  The particles of SrTiO3:Rh(2%) were prepared via the water-based h...
# 4  Nonetheless, the molten salt flux assistance has room for optimiza...
# 5  The Sr1−xCexCo0.2Fe0.8O3−δ (x = 0.0, 0.10, 0.15 and 0.20) and La0....
# 6  We used sources of thallium with a composition TlxBa2Ca2Cu3Oz (x=1...
# 7  Single crystals of Cd4YbO(BO3)3 were grown through high-temperatur...
# 8  Single crystals of TbBaMn2O6 were obtained by floating zone (FZ) m...
#
#                                                        example_reactions  \
# 0  [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Ta...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [precursors=['CaCO3', 'CuO', 'SnO2'] additives=[] target=Target(ta...
# 3  [precursors=['TiO2', 'SrCO3', 'Rh2O3'] additives=[] target=Target(...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['Tl2O3', 'BaCuO2', 'Ca2CuO3', 'Ba2Ca2Cu3O7'] additive...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=[] target=Target...
#
#                                                                reasoning  \
# 0  The text describes the preparation of perovskite nanosheets throug...
# 1  The text describes the preparation of SrTiO3 doped with rhodium (S...
# 2  The text describes the synthesis of polycrystalline samples of ACu...
# 3  The text describes two methods for preparing SrTiO3:Rh(2%) particl...
# 4  The text describes the synthesis of SnNb2O6 using a molten salt fl...
# 5  The text describes the synthesis of two types of samples: Sr1−xCex...
# 6  The text describes the preparation of a thallium-based compound wi...
# 7  The text describes the synthesis of single crystals of Cd4YbO(BO3)...
# 8  The text describes the synthesis of TbBaMn2O6 using a two-step pro...
#
#                                                           pred_reactions  \
# 0  [precursors=['K2CO3', 'CaCO3', 'Nb2O5'] additives=[] target=Target...
# 1  [precursors=['SrCO3', 'TiO2', 'Rh2O3'] additives=[] target=Target(...
# 2  [precursors=['CaCO3', 'CuO', 'SnO2'] additives=[] target=Target(ta...
# 3  [precursors=['TIPT', 'Sr(OAc)2', 'RhCl3'] additives=['acac', 'AcOH...
# 4  [precursors=['SnO', 'Nb2O5'] additives=['SnCl2'] target=Target(tar...
# 5  [Reaction(precursors=['Sr(NO3)2', 'Co(NO3)2·6H2O', 'Fe(NO3)3·6H2O'...
# 6  [precursors=['BaO2', 'CuO', 'CaO'] additives=[] target=Target(targ...
# 7  [precursors=['CdCO3', 'H3BO3', 'Yb2O3'] additives=[] target=Target...
# 8  [precursors=['Tb4O7', 'MnCO3', 'BaCO3'] additives=[] target=Target...
#
#       metric
# 0
# 1  ✔️ [True]
# 2  ✔️ [True]
# 3  ✔️ [True]
# 4  ✔️ [True]
# 5  ✔️ [True]
# 6  ✔️ [True]
# 7  ✔️ [True]
# 8
# 77.78

# %%
compiled_direct(text='The BaCe0.7In0.15Ta0.05Y0.1O3-\u03b4 (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3\u22c56H2O, In(NO3)3\u22c54.5H2O, and Y(NO3)3\u22c56H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000\u202f\u00b0C for 5\u202fh in air. In addition, the BaCe0.7Y0.3O3-\u03b4 (BCY) powder was also prepared by Pechini method and calcined at 1000\u202f\u00b0C for 5\u202fh in air.')
# Out:
# Prediction(
#     reasoning='The text describes the preparation of BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) and BaCe0.7Y0.3O3-δ (BCY) powders using a combination of solid-state reaction and the Pechini method. The process involves dissolving metal nitrates in water, adding citric acid as a complexation agent, adjusting the pH, and adding Ta2O5. The mixture is then heated to form a gel, which is ignited to form ashes. These ashes are calcined to obtain the final BCITY powder. The BCY powder is prepared similarly using the Pechini method. The Pechini method is a type of sol-gel process, which is categorized under "others" in the reaction type.',
#     reactions=[Reaction(precursors=['Ba(NO3)2', 'Ce(NO3)3·6H2O', 'In(NO3)3·4.5H2O', 'Y(NO3)3·6H2O', 'Ta2O5'], additives=['citric acid', 'ammonia water'], target=Target(target_formula='BaCe0.7In0.15Ta0.05Y0.1O3-δ', amount_var={}, extra_description='BCITY powder'), reaction_type='others'), Reaction(precursors=['Ba(NO3)2', 'Ce(NO3)3·6H2O', 'Y(NO3)3·6H2O'], additives=['citric acid', 'ammonia water'], target=Target(target_formula='BaCe0.7Y0.3O3-δ', amount_var={}, extra_description='BCY powder'), reaction_type='others')]
# )

# %%
test_text = "In 2004, Kudo and coworkers first reported the photocatalytic activities of SnNb2O6, Sn2Nb2O7, SnTa2O6 and Sn2Ta2O7 for hydrogen evolution, using methanol as the sacrificial reagent. The photocatalysts were synthesized using solid-state synthesis, and the photocatalytic activity was measured under visible irradiation for the tin niobate structures (λ > 420 nm) and under UV irradiation for the tin tantalate structures (λ > 300 nm). The two tin tantalate structures were shown to be less interesting due to their wide band gaps and low photocatalytic activity, as the hydrogen evolution activity of Sn2Ta2O7 was reported to be approximately 2.1 μmol h-1 and SnTa2O6 was found to be inactive. Interestingly, although the two tin niobate structures show similar band gaps of approximately 2.3 eV, the SnNb2O6 structure's optimized hydrogen evolution rate was found to be 18 μmol h-1, with a turnover number (TON) of 180 at 10 h. summarizes all the materials that have been used as photocatalysts for the hydrogen evolution reaction. Later in 2006, Kudo and coworkers reported the flux-assisted synthesis of SnNb2O6 starting from a Sr2Nb2O7 perovskite structure with SnCl2 as a molten salt. The synthesis proceeds through an ion exchange mechanism at a low temperature of 300 °C for a long time of 30 h, where Sn2+ replaces the Sr2+, resulting in a layered structure. Although the flux-assisted method resulted in a nanoplate material with a higher surface area in comparison to the bulk tin niobate synthesized by the solid-state method, it did not improve the activity, which may be attributed to the decreased crystallinity."
compiled_direct(text=test_text).reactions
# Out:
# [Reaction(precursors=['Sr2Nb2O7', 'SnCl2'], additives=[], target=Target(target_formula='SnNb2O6', amount_var={}, element_var={}), reaction_type='flux')]

# %%
lm.inspect_history(6)
# Out:
# [2024-12-13T14:50:19.949828]
#
# System message:
#
# Your input fields are:
# 1. `gold` (str): the gold reactions which should be extracted
# 2. `extracted` (str): the extracted reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `answer` (Literal[yes, no]): Does the extracted reactions match the gold reactions? Tolerate some minor differences
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## gold ## ]]
# {gold}
#
# [[ ## extracted ## ]]
# {extracted}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}        # note: the value you produce must be one of: yes; no
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         whether the extract reactions match the gold reactions
#
#
# User message:
#
# [[ ## gold ## ]]
# precursors: TiO2,SrCO3,Rh2O3, target: SrTiO3:Rh(2%), target amount variable: {}
# precursors: TIPT,Sr(OAc)2,RhCl3, target: SrTiO3:Rh(2%), target amount variable: {}
#
# [[ ## extracted ## ]]
# precursors: TIPT,Sr(OAc)2,RhCl3, target: SrTiO3:Rh(2%), target amount variable: {}
# precursors: TiO2,SrCO3,Rh2O3, target: SrTiO3:Rh(2%), target amount variable: {}
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]` (must be formatted as a valid Python Literal[yes, no]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The extracted reactions and the gold reactions both list the same sets of precursors and targets. The order of the reactions is reversed, but the content is identical. Since the order of reactions does not affect the equivalence of the sets, the extracted reactions match the gold reactions.
#
# [[ ## answer ## ]]
# yes
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-13T14:50:20.188699]
#
# System message:
#
# Your input fields are:
# 1. `gold` (str): the gold reactions which should be extracted
# 2. `extracted` (str): the extracted reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `answer` (Literal[yes, no]): Does the extracted reactions match the gold reactions? Tolerate some minor differences
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## gold ## ]]
# {gold}
#
# [[ ## extracted ## ]]
# {extracted}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}        # note: the value you produce must be one of: yes; no
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         whether the extract reactions match the gold reactions
#
#
# User message:
#
# [[ ## gold ## ]]
# precursors: CaCO3,CuO,SnO2, target: CaCu3Sn4O12, target amount variable: {}
# precursors: SrCO3,CuO,SnO2, target: SrCu3Sn4O12, target amount variable: {}
# precursors: PbO,CuO,SnO2, target: PbCu3Sn4O12, target amount variable: {}
#
# [[ ## extracted ## ]]
# precursors: CaCO3,CuO,SnO2, target: CaCu3Sn4O12, target amount variable: {}
# precursors: SrCO3,CuO,SnO2, target: SrCu3Sn4O12, target amount variable: {}
# precursors: PbO,CuO,SnO2, target: PbCu3Sn4O12, target amount variable: {}
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]` (must be formatted as a valid Python Literal[yes, no]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The extracted reactions match the gold reactions exactly. Each set of precursors and targets in the extracted reactions corresponds perfectly with those in the gold reactions. There are no discrepancies in the chemical formulas or the structure of the reactions.
#
# [[ ## answer ## ]]
# yes
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-13T14:50:20.626826]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         extract all chmemical reactions consitituent from the text.
#         Note: please only include those reactions in which precursors and target are explicitly mentioned in the text.
#         Intermediate reaction should be extracted as well.
#
#
# User message:
#
# [[ ## text ## ]]
# Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi2SrNa2Nb4O9", "NaNbO3"], "additives": [], "target": {"target_formula": "Bi2SrNa2Nb4O15", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Na4P2O7", "MnCO3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Mn3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "CoCO3·4H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Co3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "Ni(NO3)2·6H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Ni3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi(NO3)3", "KCl"], "additives": [], "target": {"target_formula": "BiOCl", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["BiOCl", "Ca(NO3)2"], "additives": [], "target": {"target_formula": "CaBiO2Cl", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["LiH2PO4", "Fe2O3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "LiFeP2O7", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000 °C for 5 h in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000 °C for 5 h in air.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Ba(NO3)2", "Ce(NO3)3⋅6H2O", "In(NO3)3⋅4.5H2O", "Y(NO3)3⋅6H2O", "Ta2O5"], "additives": ["citric acid"], "target": {"target_formula": "BaCe0.7In0.15Ta0.05Y0.1O3-δ", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x = 0.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (> 99%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x = 0.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x = 0.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["CaCO3", "SrCO3", "TiO2"], "additives": [], "target": {"target_formula": "Ca0.88Sr0.12TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Bi2O3", "Na2CO3", "TiO2"], "additives": [], "target": {"target_formula": "Bi0.5Na0.5TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Ca0.88Sr0.12TiO3", "Bi0.5Na0.5TiO3"], "additives": ["PVA"], "target": {"target_formula": "(1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3", "amount_var": {"x": [0.025, 0.05, 0.075, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The Sr1−xCexCo0.2Fe0.8O3−δ (x = 0.0, 0.10, 0.15 and 0.20) and La0.6Sr0.4Co0.2Fe0.8O3−δ (LSCF6428) samples were synthesized by the EDTA-citrate complexing method. Stoichiometric amounts of metal nitrate precursors Sr(NO3)2 (Alfa Aesar), Co(NO3)2·6H2O (Acros Organics), Fe(NO3)3·6H2O (Sigma Aldrich), and Ce(NO3)3·6H2O (Fisher Scientific) or La(NO3)3·6H2O (Sigma Aldrich) were dissolved in distilled water and EDTA (Ethylenediaminetetraacetic acid) was added to the solution while stirring continuously. A solution of ammonium hydroxide (NH4OH) was used to control the pH at 6. At a pH of 6 and a temperature of 60 °C, citric acid was added to the solution. The mole ratio of metal ions to EDTA and citric acid was 1:1:1.5. The mixed solution was then heated to 90 °C while stirring until a brown gel was formed. The gel was dried overnight in an oven at 150 °C, followed by grinding the formed precursors. The ground powder was calcined in air at 1100 °C for 5 h to allow the cubic perovskite phase to form. The NiO–YSZ was synthesized using a conventional solid-state method, for which the details are presented in our previous publication.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Sr(NO3)2", "Co(NO3)2·6H2O", "Fe(NO3)3·6H2O", "Ce(NO3)3·6H2O"], "additives": ["EDTA", "citric acid", "NH4OH"], "target": {"target_formula": "Sr1−xCexCo0.2Fe0.8O3−δ", "amount_var": {"x": [0.0, 0.10, 0.15, 0.20]}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["La(NO3)3·6H2O", "Sr(NO3)2", "Co(NO3)2·6H2O", "Fe(NO3)3·6H2O"], "additives": ["EDTA", "citric acid", "NH4OH"], "target": {"target_formula": "La0.6Sr0.4Co0.2Fe0.8O3−δ", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}]
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-13T14:50:20.809948]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         extract all chmemical reactions consitituent from the text.
#         Note: please only include those reactions in which precursors and target are explicitly mentioned in the text.
#         Intermediate reaction should be extracted as well.
#
#
# User message:
#
# [[ ## text ## ]]
# Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi2SrNa2Nb4O9", "NaNbO3"], "additives": [], "target": {"target_formula": "Bi2SrNa2Nb4O15", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Na4P2O7", "MnCO3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Mn3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "CoCO3·4H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Co3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "Ni(NO3)2·6H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Ni3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi(NO3)3", "KCl"], "additives": [], "target": {"target_formula": "BiOCl", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["BiOCl", "Ca(NO3)2"], "additives": [], "target": {"target_formula": "CaBiO2Cl", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["LiH2PO4", "Fe2O3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "LiFeP2O7", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000 °C for 5 h in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000 °C for 5 h in air.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["Ba(NO3)2", "Ce(NO3)3⋅6H2O", "In(NO3)3⋅4.5H2O", "Y(NO3)3⋅6H2O", "Ta2O5"], "additives": ["citric acid"], "target": {"target_formula": "BaCe0.7In0.15Ta0.05Y0.1O3-δ", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x = 0.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (> 99%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x = 0.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x = 0.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reactions ## ]]
# [{"precursors": ["CaCO3", "SrCO3", "TiO2"], "additives": [], "target": {"target_formula": "Ca0.88Sr0.12TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Bi2O3", "Na2CO3", "TiO2"], "additives": [], "target": {"target_formula": "Bi0.5Na0.5TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Ca0.88Sr0.12TiO3", "Bi0.5Na0.5TiO3"], "additives": ["PVA"], "target": {"target_formula": "(1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3", "amount_var": {"x": [0.025, 0.05, 0.075, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Perovskite nanosheets were prepared by delaminating layered perovskites according to previously described procedures. The starting material KCa2Nb3O10, prepared by a solid-state reaction, was converted into a protonic form, HCa2Nb3O10 1.5H2O, in HNO3 solution. A colloidal suspension of Ca2Nb3O10 nanosheets was synthesized by delaminating HCa2Nb3O10 1.5H2O, with tetrabutylammonium hydroxide solution (TBAOH). Sr2Nb3O10, Ca2Ta3O10, and Sr2Ta3O10 nanosheets were also synthesized by delaminating layered perovskites (KSr2Nb3O10, KCa2Ta3O10, and KSr2Ta3O10).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reactions ## ]]
# [{"precursors": ["KCa2Nb3O10"], "additives": [], "target": {"target_formula": "HCa2Nb3O10·1.5H2O", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["HCa2Nb3O10·1.5H2O"], "additives": ["TBAOH"], "target": {"target_formula": "Ca2Nb3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["KSr2Nb3O10"], "additives": ["TBAOH"], "target": {"target_formula": "Sr2Nb3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["KCa2Ta3O10"], "additives": ["TBAOH"], "target": {"target_formula": "Ca2Ta3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["KSr2Ta3O10"], "additives": ["TBAOH"], "target": {"target_formula": "Sr2Ta3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}]
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-13T14:50:21.576369]
#
# System message:
#
# Your input fields are:
# 1. `gold` (str): the gold reactions which should be extracted
# 2. `extracted` (str): the extracted reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `answer` (Literal[yes, no]): Does the extracted reactions match the gold reactions? Tolerate some minor differences
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## gold ## ]]
# {gold}
#
# [[ ## extracted ## ]]
# {extracted}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}        # note: the value you produce must be one of: yes; no
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         whether the extract reactions match the gold reactions
#
#
# User message:
#
# [[ ## gold ## ]]
# precursors: Sr(NO3)2,Co(NO3)2·6H2O,Fe(NO3)3·6H2O,Ce(NO3)3·6H2O, target: Sr1−xCexCo0.2Fe0.8O3−δ, target amount variable: {'x': [0.0, 0.1, 0.15, 0.2]}
# precursors: La(NO3)3·6H2O,Sr(NO3)2,Co(NO3)2·6H2O,Fe(NO3)3·6H2O, target: La0.6Sr0.4Co0.2Fe0.8O3−δ, target amount variable: {}
#
# [[ ## extracted ## ]]
# precursors: Sr(NO3)2,Co(NO3)2·6H2O,Fe(NO3)3·6H2O,Ce(NO3)3·6H2O, target: Sr1−xCexCo0.2Fe0.8O3−δ, target amount variable: {'x': [0.0, 0.1, 0.15, 0.2]}
# precursors: La(NO3)3·6H2O,Sr(NO3)2,Co(NO3)2·6H2O,Fe(NO3)3·6H2O, target: La0.6Sr0.4Co0.2Fe0.8O3−δ, target amount variable: {}
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]` (must be formatted as a valid Python Literal[yes, no]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The extracted reactions match the gold reactions exactly. Both sets of reactions include the same precursors and targets, and the target amount variables are identical. There are no discrepancies or missing information between the gold and extracted data.
#
# [[ ## answer ## ]]
# yes
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-13T14:50:22.502491]
#
# System message:
#
# Your input fields are:
# 1. `gold` (str): the gold reactions which should be extracted
# 2. `extracted` (str): the extracted reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `answer` (Literal[yes, no]): Does the extracted reactions match the gold reactions? Tolerate some minor differences
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## gold ## ]]
# {gold}
#
# [[ ## extracted ## ]]
# {extracted}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}        # note: the value you produce must be one of: yes; no
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         whether the extract reactions match the gold reactions
#
#
# User message:
#
# [[ ## gold ## ]]
# precursors: KCa2Nb3O10, target: HCa2Nb3O10 1.5H2O, target amount variable: {}
# precursors: HCa2Nb3O10 1.5H2O, target: Ca2Nb3O10, target amount variable: {}
# precursors: KSr2Nb3O10, target: Sr2Nb3O10, target amount variable: {}
# precursors: KCa2Ta3O10, target: Ca2Ta3O10, target amount variable: {}
# precursors: KSr2Ta3O10, target: Sr2Ta3O10, target amount variable: {}
#
# [[ ## extracted ## ]]
# precursors: KCa2Nb3O10, target: HCa2Nb3O10·1.5H2O, target amount variable: {}
# precursors: HCa2Nb3O10·1.5H2O, target: Ca2Nb3O10, target amount variable: {}
# precursors: KSr2Nb3O10, target: Sr2Nb3O10, target amount variable: {}
# precursors: KCa2Ta3O10, target: Ca2Ta3O10, target amount variable: {}
# precursors: KSr2Ta3O10, target: Sr2Ta3O10, target amount variable: {}
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]` (must be formatted as a valid Python Literal[yes, no]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The extracted reactions match the gold reactions in terms of the chemical formulas and the sequence of precursors and targets. The only difference is the use of a dot (·) in the extracted reactions to denote the hydrate form (HCa2Nb3O10·1.5H2O) instead of a space (HCa2Nb3O10 1.5H2O) in the gold reactions. This is a minor formatting difference and does not affect the chemical identity or the correctness of the reactions. Therefore, the extracted reactions can be considered to match the gold reactions.
#
# [[ ## answer ## ]]
# yes
#
# [[ ## completed ## ]]

# %%
loaded = ExtractReactionWithType()
loaded.load('compiled_direct_with_element_var')

# %%
loaded(text=test_text).reactions
# Out:
# [Reaction(precursors=['Sr2Nb2O7', 'SnCl2'], additives=[], target=Target(target_formula='SnNb2O6', amount_var={}, element_var={}), reaction_type='flux')]

# %%
lm.inspect_history()
# Out:
# [2024-12-11T16:56:14.903861]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         extract all chmemical reactions consitituent from the text.
#         Note: please only include those reactions in which precursors and target are explicitly mentioned in the text.
#         Intermediate reaction should be extracted as well.
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## text ## ]]
# The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000 °C for 5 h in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000 °C for 5 h in air.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Ba(NO3)2", "Ce(NO3)3\u22c56H2O", "In(NO3)3\u22c54.5H2O", "Y(NO3)3\u22c56H2O", "Ta2O5"], "additives": ["citric acid"], "target": {"target_formula": "BaCe0.7In0.15Ta0.05Y0.1O3-\u03b4", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x = 0.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (> 99%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x = 0.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x = 0.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 ceramics using a solid-state reaction method. The precursors used are CaCO3, SrCO3, Bi2O3, Na2CO3, and TiO2. The process involves separate synthesis of CST and BNT powders, which are then mixed in varying ratios to form the final ceramics. The synthesis involves milling, calcination, re-milling, granulation with a binder, and sintering. The target compounds are the mixed ceramics with varying x values, which are analyzed using XRD and SEM.
#
# [[ ## reactions ## ]]
# [{"precursors": ["CaCO3", "SrCO3", "TiO2"], "additives": [], "target": {"target_formula": "(Ca0.88Sr0.12)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Bi2O3", "Na2CO3", "TiO2"], "additives": [], "target": {"target_formula": "(Bi0.5Na0.5)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["(Ca0.88Sr0.12)TiO3", "(Bi0.5Na0.5)TiO3"], "additives": [], "target": {"target_formula": "(1\u2212x)(Ca0.88Sr0.12)TiO3\u2013x(Bi0.5Na0.5)TiO3", "amount_var": {"x": [0.025, 0.05, 0.075, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text mentions the synthesis of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 through a solid-state reaction. The precursors for this reaction are explicitly mentioned as Bi2SrNa2Nb4O9 and NaNbO3. The reaction type is identified as a solid-state reaction due to the high temperature (1100 °C) used in the process. No additives are mentioned in the text.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi2SrNa2Nb4O9", "NaNbO3"], "additives": [], "target": {"target_formula": "Bi2SrNa2Nb4O15", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of new phases Na4M3(PO4)2(P2O7) where M can be Mn, Co, or Ni. The synthesis is carried out using a solid-state reaction method. The precursors used are Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4. The process involves heating the mixtures to decompose and remove volatile species, followed by a series of heat treatments at increasing temperatures. The target compounds are Na4Mn3(PO4)2(P2O7), Na4Co3(PO4)2(P2O7), and Na4Ni3(PO4)2(P2O7).
#
# [[ ## reactions ## ]]
# [{"precursors": ["Na4P2O7", "MnCO3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Mn3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "CoCO3\u00b74H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Co3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "Ni(NO3)2\u00b76H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Ni3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes a two-step process for preparing CaBiO2Cl. In the first step, Bi(NO3)3 and KCl are mixed in water to form a white precipitate, which is identified as BiOCl after drying. In the second step, BiOCl is reacted with Ca(NO3)2 in a solid-state reaction to form CaBiO2Cl. The text also mentions the preparation of TiO2-xNx, but it does not provide details about the precursors or the reaction process, so it cannot be included as a reaction. Therefore, the reactions that can be extracted are the formation of BiOCl from Bi(NO3)3 and KCl, and the formation of CaBiO2Cl from BiOCl and Ca(NO3)2.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi(NO3)3", "KCl"], "additives": [], "target": {"target_formula": "BiOCl", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["BiOCl", "Ca(NO3)2"], "additives": [], "target": {"target_formula": "CaBiO2Cl", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of polycrystalline LiFeP2O7 using a solid-state reaction method. The precursors used in the reaction are LiH2PO4, Fe2O3, and NH4H2PO4. These materials are mixed in stoichiometric amounts, ground, and then subjected to a series of heating steps to facilitate the reaction and form the target compound, LiFeP2O7. The process involves heating at different temperatures with intermittent regrinding to ensure thorough mixing and reaction completion. The final product's purity is confirmed using powder X-ray diffraction (XRD).
#
# [[ ## reactions ## ]]
# [{"precursors": ["LiH2PO4", "Fe2O3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "LiFeP2O7", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# In 2004, Kudo and coworkers first reported the photocatalytic activities of SnNb2O6, Sn2Nb2O7, SnTa2O6 and Sn2Ta2O7 for hydrogen evolution, using methanol as the sacrificial reagent. The photocatalysts were synthesized using solid-state synthesis, and the photocatalytic activity was measured under visible irradiation for the tin niobate structures (λ > 420 nm) and under UV irradiation for the tin tantalate structures (λ > 300 nm). The two tin tantalate structures were shown to be less interesting due to their wide band gaps and low photocatalytic activity, as the hydrogen evolution activity of Sn2Ta2O7 was reported to be approximately 2.1 μmol h-1 and SnTa2O6 was found to be inactive. Interestingly, although the two tin niobate structures show similar band gaps of approximately 2.3 eV, the SnNb2O6 structure's optimized hydrogen evolution rate was found to be 18 μmol h-1, with a turnover number (TON) of 180 at 10 h. summarizes all the materials that have been used as photocatalysts for the hydrogen evolution reaction. Later in 2006, Kudo and coworkers reported the flux-assisted synthesis of SnNb2O6 starting from a Sr2Nb2O7 perovskite structure with SnCl2 as a molten salt. The synthesis proceeds through an ion exchange mechanism at a low temperature of 300 °C for a long time of 30 h, where Sn2+ replaces the Sr2+, resulting in a layered structure. Although the flux-assisted method resulted in a nanoplate material with a higher surface area in comparison to the bulk tin niobate synthesized by the solid-state method, it did not improve the activity, which may be attributed to the decreased crystallinity.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The text describes two synthesis methods for tin niobate and tin tantalate photocatalysts. The first method is a solid-state synthesis used to prepare SnNb2O6, Sn2Nb2O7, SnTa2O6, and Sn2Ta2O7. However, the specific precursors for these solid-state reactions are not mentioned in the text, so we cannot extract detailed reactions for them. The second method is a flux-assisted synthesis of SnNb2O6, which involves starting from a Sr2Nb2O7 perovskite structure and using SnCl2 as a molten salt. This process involves an ion exchange mechanism where Sn2+ replaces Sr2+ at a low temperature, resulting in a layered SnNb2O6 structure. The flux-assisted synthesis provides enough detail to extract a reaction, as it specifies the starting material (Sr2Nb2O7) and the flux (SnCl2).
#
# [[ ## reactions ## ]]
# [{"precursors": ["Sr2Nb2O7", "SnCl2"], "additives": [], "target": {"target_formula": "SnNb2O6", "amount_var": {}, "element_var": {}}, "reaction_type": "flux"}]
#
# [[ ## completed ## ]]

# %%
compiled_program = ExtractReactionWithType()
compiled_program.load('compiled_direct_with_element_var_version_2')

# %%
compiled_program.predictor.extended_signature
# Out:
# StringSignature(text -> reasoning, reactions
#     instructions='Identify and extract all chemical reactions from the text. For each reaction:\n\nInclude reactions where precursors and target products are explicitly mentioned.\nEnsure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.\nAlso extract intermediate reactions and label them as such.'
#     text = Field(annotation=str required=True json_schema_extra={'desc': 'a piece of text which may contains chemical reactions', '__dspy_field_type': 'input', 'prefix': 'Text:'})
#     reasoning = Field(annotation=str required=True json_schema_extra={'prefix': "Reasoning: Let's think step by step in order to", 'desc': '${reasoning}', '__dspy_field_type': 'output'})
#     reactions = Field(annotation=Union[list[Reaction], NoneType] required=True json_schema_extra={'desc': 'the reactions extracted from the text, return null if no reaction found', '__dspy_field_type': 'output', 'prefix': 'Reactions:'})
# )

# %%
text_for_test = """Polycrystalline BaGa2S4:Eu2+ sample were synthesised from BaS and Ga2S3 sulphide powders mixed in stoichiometric composition and annealed at 900 °C under a stream of H2S+Ar for 4 h. The doping ions were introduced in the form of EuF3. This preparation method is different from that reported by Peters et al. [11] and Davolos et al. [13] who had used barium carbonate (BaCO3), gallium oxide (Ga2O3) and europium oxide (Eu2O3) as starting materials and H2S gas as sulphuring agent. A third preparation method presented by Donohue et al. was based on solid-state reactions between Ba and Ga in elemental form and europium sulphide EuS [14]. The method presented here provides powder samples with good crystalline properties as shown by X-ray diffraction measurements. Powder samples with varying Eu2+ concentrations (1, 5 and 10%) were studied. The samples exhibit a brownish yellow colour."""

# %%
compiled_program(text=text_for_test).reactions
# Out:
# [Reaction(precursors=['BaS', 'Ga2S3', 'EuF3'], additives=[], target=Target(target_formula='BaGa2S4:Eu2+', amount_var={'Eu2+': [0.01, 0.05, 0.1]}, element_var={}), reaction_type='solid-state')]

# %%
uncompiled_direct = ExtractReactionWithType()
uncompiled_direct.predictor.extended_signature.instructions = compiled_program.predictor.extended_signature.instructions

# %%
uncompiled_direct(text=text_for_test).reactions
# Out:
# [Reaction(precursors=['BaS', 'Ga2S3'], additives=['EuF3', 'H2S', 'Ar'], target=Target(target_formula='BaGa2S4:Eu2+', amount_var={}, element_var={}), reaction_type='solid-state'),
#  Reaction(precursors=['BaCO3', 'Ga2O3', 'Eu2O3'], additives=['H2S'], target=Target(target_formula='BaGa2S4:Eu2+', amount_var={}, element_var={}), reaction_type='solid-state'),
#  Reaction(precursors=['Ba', 'Ga', 'EuS'], additives=[], target=Target(target_formula='BaGa2S4:Eu2+', amount_var={}, element_var={}), reaction_type='solid-state')]

# %%
lm.inspect_history(3)
# Out:
# [2024-12-12T10:29:07.733580]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Identify and extract all chemical reactions from the text. For each reaction:
#
#         Include reactions where precursors and target products are explicitly mentioned.
#         Ensure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.
#         Also extract intermediate reactions and label them as such.
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline BaGa2S4:Eu2+ sample were synthesised from BaS and Ga2S3 sulphide powders mixed in stoichiometric composition and annealed at 900 °C under a stream of H2S+Ar for 4 h. The doping ions were introduced in the form of EuF3. This preparation method is different from that reported by Peters et al. [11] and Davolos et al. [13] who had used barium carbonate (BaCO3), gallium oxide (Ga2O3) and europium oxide (Eu2O3) as starting materials and H2S gas as sulphuring agent. A third preparation method presented by Donohue et al. was based on solid-state reactions between Ba and Ga in elemental form and europium sulphide EuS [14]. The method presented here provides powder samples with good crystalline properties as shown by X-ray diffraction measurements. Powder samples with varying Eu2+ concentrations (1, 5 and 10%) were studied. The samples exhibit a brownish yellow colour.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The text describes three different methods for synthesizing BaGa2S4:Eu2+ samples. Each method involves different precursors and additives, and the target product is the same. The first method uses BaS and Ga2S3 as precursors and EuF3 as a doping additive, with H2S+Ar as the reaction atmosphere. The second method, mentioned as used by Peters et al. and Davolos et al., involves BaCO3, Ga2O3, and Eu2O3 as precursors with H2S as the sulphuring agent. The third method by Donohue et al. uses elemental Ba and Ga with EuS. All methods aim to produce BaGa2S4:Eu2+ as the target compound. The reactions can be classified as solid-state reactions based on the description.
#
# [[ ## reactions ## ]]
# [
#     {
#         "precursors": ["BaS", "Ga2S3"],
#         "additives": ["EuF3", "H2S", "Ar"],
#         "target": {
#             "target_formula": "BaGa2S4:Eu2+",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "solid-state"
#     },
#     {
#         "precursors": ["BaCO3", "Ga2O3", "Eu2O3"],
#         "additives": ["H2S"],
#         "target": {
#             "target_formula": "BaGa2S4:Eu2+",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "solid-state"
#     },
#     {
#         "precursors": ["Ba", "Ga", "EuS"],
#         "additives": [],
#         "target": {
#             "target_formula": "BaGa2S4:Eu2+",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "solid-state"
#     }
# ]
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-12T10:30:00.284714]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Identify and extract all chemical reactions from the text. For each reaction:
#
#         Include reactions where precursors and target products are explicitly mentioned.
#         Ensure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.
#         Also extract intermediate reactions and label them as such.
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## text ## ]]
# The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000 °C for 5 h in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000 °C for 5 h in air.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Ba(NO3)2", "Ce(NO3)3\u22c56H2O", "In(NO3)3\u22c54.5H2O", "Y(NO3)3\u22c56H2O", "Ta2O5"], "additives": ["citric acid"], "target": {"target_formula": "BaCe0.7In0.15Ta0.05Y0.1O3-\u03b4", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x = 0.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (> 99%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x = 0.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x = 0.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the preparation of (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 ceramics using a solid-state reaction method. The precursors used are CaCO3, SrCO3, Bi2O3, Na2CO3, and TiO2. The process involves synthesizing CST and BNT powders separately, followed by calcination and re-milling. The final ceramics are formed by pressing and sintering the powders. The target products are the (1−x)CST–xBNT ceramics with varying x values. The reaction type is solid-state, and the additives include poly vinyl alcohol (PVA) used as a binder.
#
# [[ ## reactions ## ]]
# [{"precursors": ["CaCO3", "SrCO3", "TiO2"], "additives": ["PVA"], "target": {"target_formula": "(Ca0.88Sr0.12)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Bi2O3", "Na2CO3", "TiO2"], "additives": ["PVA"], "target": {"target_formula": "(Bi0.5Na0.5)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["(Ca0.88Sr0.12)TiO3", "(Bi0.5Na0.5)TiO3"], "additives": ["PVA"], "target": {"target_formula": "(1\u2212x)(Ca0.88Sr0.12)TiO3\u2013x(Bi0.5Na0.5)TiO3", "amount_var": {"x": [0.025, 0.05, 0.075, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text mentions a solid-state reaction involving Bi2SrNa2Nb4O9 and NaNbO3 to synthesize a new four-layer Aurivillius phase, Bi2SrNa2Nb4O15. This is the only chemical reaction explicitly described in the text, with both the precursors and the target product clearly identified. The reaction type is specified as a solid-state reaction.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi2SrNa2Nb4O9", "NaNbO3"], "additives": [], "target": {"target_formula": "Bi2SrNa2Nb4O15", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of new phases Na4M3(PO4)2(P2O7) where M can be Mn, Co, or Ni. The synthesis is carried out using a solid-state reaction method. The precursors used are Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4. The process involves heating the mixture to decompose and remove volatile species, followed by a series of heat treatments at increasing temperatures. The target compounds are Na4Mn3(PO4)2(P2O7), Na4Co3(PO4)2(P2O7), and Na4Ni3(PO4)2(P2O7), corresponding to the different metal ions used.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Na4P2O7", "MnCO3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Mn3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "CoCO3\u00b74H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Co3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "Ni(NO3)2\u00b76H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Ni3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes a two-step process for synthesizing CaBiO2Cl. In the first step, Bi(NO3)3 and KCl are mixed in water to form a white precipitate, which is identified as BiOCl after drying. In the second step, BiOCl is reacted with Ca(NO3)2 in a solid-state reaction to form CaBiO2Cl. The text also mentions the preparation of TiO2-xNx, but it does not provide details on the precursors or the method used, so it cannot be considered a complete reaction for extraction.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi(NO3)3", "KCl"], "additives": [], "target": {"target_formula": "BiOCl", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["BiOCl", "Ca(NO3)2"], "additives": [], "target": {"target_formula": "CaBiO2Cl", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of polycrystalline LiFeP2O7 using a solid-state reaction method. The precursors used in the reaction are LiH2PO4, Fe2O3, and NH4H2PO4. These materials are mixed in stoichiometric amounts, ground, and then subjected to a series of heating steps to facilitate the reaction and decomposition of ammonium dihydrogen phosphate. The final product, LiFeP2O7, is confirmed by powder X-ray diffraction (XRD) analysis.
#
# [[ ## reactions ## ]]
# [{"precursors": ["LiH2PO4", "Fe2O3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "LiFeP2O7", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline BaGa2S4:Eu2+ sample were synthesised from BaS and Ga2S3 sulphide powders mixed in stoichiometric composition and annealed at 900 °C under a stream of H2S+Ar for 4 h. The doping ions were introduced in the form of EuF3. This preparation method is different from that reported by Peters et al. [11] and Davolos et al. [13] who had used barium carbonate (BaCO3), gallium oxide (Ga2O3) and europium oxide (Eu2O3) as starting materials and H2S gas as sulphuring agent. A third preparation method presented by Donohue et al. was based on solid-state reactions between Ba and Ga in elemental form and europium sulphide EuS [14]. The method presented here provides powder samples with good crystalline properties as shown by X-ray diffraction measurements. Powder samples with varying Eu2+ concentrations (1, 5 and 10%) were studied. The samples exhibit a brownish yellow colour.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of polycrystalline BaGa2S4:Eu2+ using a solid-state reaction method. The precursors used are BaS and Ga2S3, with EuF3 as the source of doping ions. The reaction is carried out by annealing the mixture at 900 °C under a stream of H2S+Ar gas. The text also mentions alternative methods using different starting materials, but the focus is on the method using BaS, Ga2S3, and EuF3. The target product is BaGa2S4 doped with Eu2+, and the reaction type is solid-state.
#
# [[ ## reactions ## ]]
# [{"precursors": ["BaS", "Ga2S3", "EuF3"], "additives": [], "target": {"target_formula": "BaGa2S4:Eu2+", "amount_var": {"Eu2+": [0.01, 0.05, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-12T10:43:20.104097]
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## text ## ]]
# The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000 °C for 5 h in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000 °C for 5 h in air.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Ba(NO3)2", "Ce(NO3)3\u22c56H2O", "In(NO3)3\u22c54.5H2O", "Y(NO3)3\u22c56H2O", "Ta2O5"], "additives": ["citric acid"], "target": {"target_formula": "BaCe0.7In0.15Ta0.05Y0.1O3-\u03b4", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x = 0.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (> 99%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x = 0.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x = 0.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the preparation of (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 ceramics using a solid-state reaction method. The precursors used are CaCO3, SrCO3, Bi2O3, Na2CO3, and TiO2. The process involves synthesizing CST and BNT powders separately, followed by calcination and re-milling. The final ceramics are formed by pressing and sintering the powders. The target products are the (1−x)CST–xBNT ceramics with varying x values. The reaction type is solid-state, and the additives include poly vinyl alcohol (PVA) used as a binder.
#
# [[ ## reactions ## ]]
# [{"precursors": ["CaCO3", "SrCO3", "TiO2"], "additives": ["PVA"], "target": {"target_formula": "(Ca0.88Sr0.12)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Bi2O3", "Na2CO3", "TiO2"], "additives": ["PVA"], "target": {"target_formula": "(Bi0.5Na0.5)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["(Ca0.88Sr0.12)TiO3", "(Bi0.5Na0.5)TiO3"], "additives": ["PVA"], "target": {"target_formula": "(1\u2212x)(Ca0.88Sr0.12)TiO3\u2013x(Bi0.5Na0.5)TiO3", "amount_var": {"x": [0.025, 0.05, 0.075, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text mentions a solid-state reaction involving Bi2SrNa2Nb4O9 and NaNbO3 to synthesize a new four-layer Aurivillius phase, Bi2SrNa2Nb4O15. This is the only chemical reaction explicitly described in the text, with both the precursors and the target product clearly identified. The reaction type is specified as a solid-state reaction.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi2SrNa2Nb4O9", "NaNbO3"], "additives": [], "target": {"target_formula": "Bi2SrNa2Nb4O15", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of new phases Na4M3(PO4)2(P2O7) where M can be Mn, Co, or Ni. The synthesis is carried out using a solid-state reaction method. The precursors used are Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4. The process involves heating the mixture to decompose and remove volatile species, followed by a series of heat treatments at increasing temperatures. The target compounds are Na4Mn3(PO4)2(P2O7), Na4Co3(PO4)2(P2O7), and Na4Ni3(PO4)2(P2O7), corresponding to the different metal ions used.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Na4P2O7", "MnCO3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Mn3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "CoCO3\u00b74H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Co3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "Ni(NO3)2\u00b76H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Ni3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes a two-step process for synthesizing CaBiO2Cl. In the first step, Bi(NO3)3 and KCl are mixed in water to form a white precipitate, which is identified as BiOCl after drying. In the second step, BiOCl is reacted with Ca(NO3)2 in a solid-state reaction to form CaBiO2Cl. The text also mentions the preparation of TiO2-xNx, but it does not provide details on the precursors or the method used, so it cannot be considered a complete reaction for extraction.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi(NO3)3", "KCl"], "additives": [], "target": {"target_formula": "BiOCl", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["BiOCl", "Ca(NO3)2"], "additives": [], "target": {"target_formula": "CaBiO2Cl", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Identify and extract all chemical reactions from the text. For each reaction:
#
#         Include reactions where precursors and target products are explicitly mentioned.
#         Ensure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.
#         Also extract intermediate reactions and label them as such.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of polycrystalline LiFeP2O7 using a solid-state reaction method. The precursors used in the reaction are LiH2PO4, Fe2O3, and NH4H2PO4. These materials are mixed in stoichiometric amounts, ground, and then subjected to a series of heating steps to facilitate the reaction and decomposition of ammonium dihydrogen phosphate. The final product, LiFeP2O7, is confirmed by powder X-ray diffraction (XRD) analysis.
#
# [[ ## reactions ## ]]
# [{"precursors": ["LiH2PO4", "Fe2O3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "LiFeP2O7", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline BaGa2S4:Eu2+ sample were synthesised from BaS and Ga2S3 sulphide powders mixed in stoichiometric composition and annealed at 900 °C under a stream of H2S+Ar for 4 h. The doping ions were introduced in the form of EuF3. This preparation method is different from that reported by Peters et al. [11] and Davolos et al. [13] who had used barium carbonate (BaCO3), gallium oxide (Ga2O3) and europium oxide (Eu2O3) as starting materials and H2S gas as sulphuring agent. A third preparation method presented by Donohue et al. was based on solid-state reactions between Ba and Ga in elemental form and europium sulphide EuS [14]. The method presented here provides powder samples with good crystalline properties as shown by X-ray diffraction measurements. Powder samples with varying Eu2+ concentrations (1, 5 and 10%) were studied. The samples exhibit a brownish yellow colour.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of polycrystalline BaGa2S4:Eu2+ using a solid-state reaction method. The primary precursors for this synthesis are BaS and Ga2S3, which are mixed in stoichiometric amounts and annealed under a stream of H2S+Ar. The doping ions are introduced using EuF3. The text also mentions alternative methods used by other researchers, but the focus is on the method using BaS, Ga2S3, and EuF3. The target product is BaGa2S4 doped with Eu2+ ions, and the reaction type is solid-state.
#
# [[ ## reactions ## ]]
# [{"precursors": ["BaS", "Ga2S3", "EuF3"], "additives": [], "target": {"target_formula": "BaGa2S4:Eu2+", "amount_var": {"Eu2+": [0.01, 0.05, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]

# %%
class SwappedChatAdapter(dspy.adapters.ChatAdapter):
    def format(self, signature, demos, inputs):
        messages:list = super().format(signature, demos, inputs)
        systeme_message = messages.pop(0)
        messages.insert(-2, systeme_message)
        return messages

dspy.configure(adapter=SwappedChatAdapter())
with dspy.context(lm=dspy.LM('openai/gpt-4o')):
    res = compiled_program(text=text_for_test)
    print(res.reasoning, '\n', res.reactions)
# Out:
# The text describes the synthesis of polycrystalline BaGa2S4:Eu2+ using a solid-state reaction method. The precursors used in this method are BaS, Ga2S3, and EuF3. The mixture is annealed at 900 °C under a stream of H2S+Ar gas. The text also mentions alternative methods used by other researchers, but the focus is on the method using BaS and Ga2S3. The target product is BaGa2S4 doped with Eu2+ ions, with varying concentrations of Eu2+ (1, 5, and 10%).
#  [Reaction(precursors=['BaS', 'Ga2S3', 'EuF3'], additives=[], target=Target(target_formula='BaGa2S4:Eu2+', amount_var={'Eu2+': [0.01, 0.05, 0.1]}, element_var={}), reaction_type='solid-state')]

# %%
compiled_program(text=dev[0])
# Out:
# Prediction(
#     reasoning='The text describes the preparation of perovskite nanosheets through a series of chemical transformations. The starting material, KCa2Nb3O10, is first converted into a protonic form, HCa2Nb3O10 1.5H2O, using HNO3. This intermediate is then delaminated using tetrabutylammonium hydroxide (TBAOH) to produce Ca2Nb3O10 nanosheets. Additionally, other nanosheets such as Sr2Nb3O10, Ca2Ta3O10, and Sr2Ta3O10 are synthesized by delaminating their respective layered perovskites (KSr2Nb3O10, KCa2Ta3O10, and KSr2Ta3O10). Each step involves a transformation of a precursor into a target product, often with the aid of an additive.',
#     reactions=[Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Target(target_formula='HCa2Nb3O10 1.5H2O', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['HCa2Nb3O10 1.5H2O'], additives=['TBAOH'], target=Target(target_formula='Ca2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Nb3O10'], additives=[], target=Target(target_formula='Sr2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KCa2Ta3O10'], additives=[], target=Target(target_formula='Ca2Ta3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Ta3O10'], additives=[], target=Target(target_formula='Sr2Ta3O10', amount_var={}, element_var={}), reaction_type='others')]
# )

# %%
uncompiled_direct(text=dev[0])
# Out:
# Prediction(
#     reasoning='The text describes the preparation of perovskite nanosheets through a series of chemical reactions. The reactions involve the conversion of layered perovskites into their protonic forms and subsequent delamination to form nanosheets. The text explicitly mentions the starting materials, additives, and target products for each reaction, allowing for the extraction of detailed reaction information. The reactions are not categorized under typical reaction types like solid-state or sol-gel, so they are labeled as "others."',
#     reactions=[Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Target(target_formula='HCa2Nb3O10 1.5H2O', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['HCa2Nb3O10 1.5H2O'], additives=['TBAOH'], target=Target(target_formula='Ca2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Nb3O10'], additives=[], target=Target(target_formula='Sr2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KCa2Ta3O10'], additives=[], target=Target(target_formula='Ca2Ta3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Ta3O10'], additives=[], target=Target(target_formula='Sr2Ta3O10', amount_var={}, element_var={}), reaction_type='others')]
# )

# %%
lm.inspect_history(2)
# Out:
# [2024-12-12T11:08:35.720688]
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## text ## ]]
# The BaCe0.7In0.15Ta0.05Y0.1O3-δ (BCITY) powder was prepared by combing solid state reaction and Pechini method to ensure homogeneity of mixed oxides. Firstly, the Ba(NO3)2, Ce(NO3)3⋅6H2O, In(NO3)3⋅4.5H2O, and Y(NO3)3⋅6H2O with the stoichiometric amounts were dissolved in deionized water. Secondly, the citric acid, as a complexation agent, was added with the molar ratio (3:2) of citric acid to metal ions. After the pH value of the solution was adjusted to be 7 by adding appropriate ammonia water, the stoichiometric amount of Ta2O5 was added. Thirdly, the solution added with Ta2O5 was stirred continuously during heating to evaporate water until it was changed into viscous gel and finally ignited to flame, which resulted in the formation of some white ashes. Finally, the BCITY powder was obtained by calcining the white ashes at 1000 °C for 5 h in air. In addition, the BaCe0.7Y0.3O3-δ (BCY) powder was also prepared by Pechini method and calcined at 1000 °C for 5 h in air.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Ba(NO3)2", "Ce(NO3)3\u22c56H2O", "In(NO3)3\u22c54.5H2O", "Y(NO3)3\u22c56H2O", "Ta2O5"], "additives": ["citric acid"], "target": {"target_formula": "BaCe0.7In0.15Ta0.05Y0.1O3-\u03b4", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 [hereafter referred to as (1−x)CST–xBNT] ceramics (x = 0.025, 0.050, 0.075, 0.10) were prepared by the conventional solid-state reaction method. The starting materials were high-purity grade powders (> 99%): CaCO3, SrCO3, Bi2O3, Na2CO3 and TiO2. CST and BNT powders were synthesized separately by mixing the starting materials according to the desired stoichiometry, and milled with ZrO2 balls and deionized water for 6 h in nylon jars. After drying, the powders were calcined at 1100 °C for 3 h and 850 °C for 3 h, respectively. The resulting powders were re-milled for 6 h. After that, the dried and re-milled mixtures were granulated with appropriate poly vinyl alcohol (PVA) as binder and uniaxial pressed at 300 MPa into cylinders with approximate size of 15 mm in diameter and 7.3 mm in thickness. The cylinders with x = 0.05, 0.075 and 0.1 were sintered in air at 1225–1300 °C for 3 h, and the cylinders with x = 0.025 were sintered in air at 1275–1375 °C for 3 h. Phase identification of the sintered products were analysed by X-ray diffraction (XRD; RIGAKU; SmartLab 3) using CuKα radiation. Microstructures of the surfaces were investigated by a scanning electron microscopy (SEM; JEOL, JSM-5900) with an accelerating voltage of 15 kV.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the preparation of (1−x)(Ca0.88Sr0.12)TiO3–x(Bi0.5Na0.5)TiO3 ceramics using a solid-state reaction method. The precursors used are CaCO3, SrCO3, Bi2O3, Na2CO3, and TiO2. The process involves synthesizing CST and BNT powders separately, followed by calcination and re-milling. The final ceramics are formed by pressing and sintering the powders. The target products are the (1−x)CST–xBNT ceramics with varying x values. The reaction type is solid-state, and the additives include poly vinyl alcohol (PVA) used as a binder.
#
# [[ ## reactions ## ]]
# [{"precursors": ["CaCO3", "SrCO3", "TiO2"], "additives": ["PVA"], "target": {"target_formula": "(Ca0.88Sr0.12)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Bi2O3", "Na2CO3", "TiO2"], "additives": ["PVA"], "target": {"target_formula": "(Bi0.5Na0.5)TiO3", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["(Ca0.88Sr0.12)TiO3", "(Bi0.5Na0.5)TiO3"], "additives": ["PVA"], "target": {"target_formula": "(1\u2212x)(Ca0.88Sr0.12)TiO3\u2013x(Bi0.5Na0.5)TiO3", "amount_var": {"x": [0.025, 0.05, 0.075, 0.1]}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Three interesting papers published during this review period demonstrated the ability of XRF techniques to give chemical information on multilayered structures. Doomes and McGuire391 reported their work on ion beam sputtered multilayer SiO2/Ta2O5 coatings on fused SiO2 substrates. XAS gave chemical and structural features of the dielectric multilayered NO2/Ta2O5 mirror coatings. Rajput et al.392 studied the depth resolved structural information of heavy ion induced phase formation in Si/Fe/Si trilayers. XRF measurements gave the Fe depth distribution, whilst Mossbauer spectroscopy and XAFS provided information about changes in local structure. Synthesis and characterisation of a new four-layer Aurivillius phase Bi2SrNa2Nb4O15 was reported by Liang et al.393 Following a solid state reaction of Bi2SrNa2Nb4O9 and NaNbO3 at 1100 °C, XRD was used to show the resultant crystalline structure and XRF and thermogravimetry used for the measurement of composition the multilayers formed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text mentions a solid-state reaction involving Bi2SrNa2Nb4O9 and NaNbO3 to synthesize a new four-layer Aurivillius phase, Bi2SrNa2Nb4O15. This is the only chemical reaction explicitly described in the text, with both the precursors and the target product clearly identified. The reaction type is specified as a solid-state reaction.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi2SrNa2Nb4O9", "NaNbO3"], "additives": [], "target": {"target_formula": "Bi2SrNa2Nb4O15", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# The new phases, Na4M3(PO4)2(P2O7) (M = Mn, Co, Ni), were also obtained as a microcrystalline powder by solid-state reaction, employing as precursors Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4, in the same molar ratios used to obtain single crystals. The mixtures were heated at 300 °C in a porcelain crucible to decompose and remove the volatile species. Then, accumulative treatments for 24 h each at 400, 500, 600, and 700 °C for manganese and cobalt samples and up to 800 °C in the case of the nickel sample were performed.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of new phases Na4M3(PO4)2(P2O7) where M can be Mn, Co, or Ni. The synthesis is carried out using a solid-state reaction method. The precursors used are Na4P2O7, MnCO3, CoCO3·4H2O, Ni(NO3)2·6H2O, and NH4H2PO4. The process involves heating the mixture to decompose and remove volatile species, followed by a series of heat treatments at increasing temperatures. The target compounds are Na4Mn3(PO4)2(P2O7), Na4Co3(PO4)2(P2O7), and Na4Ni3(PO4)2(P2O7), corresponding to the different metal ions used.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Na4P2O7", "MnCO3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Mn3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "CoCO3\u00b74H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Co3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}, {"precursors": ["Na4P2O7", "Ni(NO3)2\u00b76H2O", "NH4H2PO4"], "additives": [], "target": {"target_formula": "Na4Ni3(PO4)2(P2O7)", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# CaBiO2Cl samples were prepared by a two-step process. All chemicals used were analytic grade reagents without further purification. The starting materials of Bi(NO3)3 and KCl (1:1 molar ratio) were mixed together, and then 60 mL of distilled water was added. White precipitate appeared immediately and was stirred for 5 h to complete the precipitation reaction. The precipitate was collected and washed with deionized water thoroughly and dried at 80 °C in air. The final BiOCl powder was obtained as seen from XRD patterns (see Fig. S1 in ESI†). In what followed, BiOCl and Ca(NO3)2 (1:1 molar ratio) were used to synthesize CaBiO2Cl by a solid-state reaction. The reactant powders were thoroughly ground together into a homogeneous mixture using a mortar and pestle, transferred to an alumina crucible, and subsequently heated in air at different temperatures for 12 h. A pale yellow polycrystalline powder (CaBiO2Cl) was obtained from the reactions. TiO2-xNx known for its good photocatalytic activity in the decomposition of pollutants under visible-light irradiation, was also prepared as a reference.
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes a two-step process for synthesizing CaBiO2Cl. In the first step, Bi(NO3)3 and KCl are mixed in water to form a white precipitate, which is identified as BiOCl after drying. In the second step, BiOCl is reacted with Ca(NO3)2 in a solid-state reaction to form CaBiO2Cl. The text also mentions the preparation of TiO2-xNx, but it does not provide details on the precursors or the method used, so it cannot be considered a complete reaction for extraction.
#
# [[ ## reactions ## ]]
# [{"precursors": ["Bi(NO3)3", "KCl"], "additives": [], "target": {"target_formula": "BiOCl", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["BiOCl", "Ca(NO3)2"], "additives": [], "target": {"target_formula": "CaBiO2Cl", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Polycrystalline LiFeP2O7 was synthesized by solid-state methods. Stoichiometric amounts of LiH2PO4 (Alfa Aesar, 97%), Fe2O3 (Fisher Scientific, Certified), and NH4H2PO4 (Alfa Aesar, 98.0%) were ground thoroughly, packed tightly in a platinum crucible, and heated to 200 °C for 10 h to decompose ammonium dihydrogen phosphate, and then 600 °C for 20 h and 850 °C for 20 h with intermittent regrindings. The purity of polycrystalline LiFeP2O7 was confirmed by powder XRD (see Figure S1).
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Identify and extract all chemical reactions from the text. For each reaction:
#
#         Include reactions where precursors and target products are explicitly mentioned.
#         Ensure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.
#         Also extract intermediate reactions and label them as such.
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# The text describes the synthesis of polycrystalline LiFeP2O7 using a solid-state reaction method. The precursors used in the reaction are LiH2PO4, Fe2O3, and NH4H2PO4. These materials are mixed in stoichiometric amounts, ground, and then subjected to a series of heating steps to facilitate the reaction and decomposition of ammonium dihydrogen phosphate. The final product, LiFeP2O7, is confirmed by powder X-ray diffraction (XRD) analysis.
#
# [[ ## reactions ## ]]
# [{"precursors": ["LiH2PO4", "Fe2O3", "NH4H2PO4"], "additives": [], "target": {"target_formula": "LiFeP2O7", "amount_var": {}, "element_var": {}}, "reaction_type": "solid-state"}]
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## text ## ]]
# Example({'text': 'Perovskite nanosheets were prepared by delaminating layered perovskites according to previously described procedures. The starting material KCa2Nb3O10, prepared by a solid-state reaction, was converted into a protonic form, HCa2Nb3O10 1.5H2O, in HNO3 solution. A colloidal suspension of Ca2Nb3O10 nanosheets was synthesized by delaminating HCa2Nb3O10 1.5H2O, with tetrabutylammonium hydroxide solution (TBAOH). Sr2Nb3O10, Ca2Ta3O10, and Sr2Ta3O10 nanosheets were also synthesized by delaminating layered perovskites (KSr2Nb3O10, KCa2Ta3O10, and KSr2Ta3O10).', 'reactions': [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Target(target_formula='HCa2Nb3O10 1.5H2O', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['HCa2Nb3O10 1.5H2O'], additives=['TBAOH'], target=Target(target_formula='Ca2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Nb3O10'], additives=[], target=Target(target_formula='Sr2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KCa2Ta3O10'], additives=[], target=Target(target_formula='Ca2Ta3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Ta3O10'], additives=[], target=Target(target_formula='Sr2Ta3O10', amount_var={}, element_var={}), reaction_type='others')]}) (input_keys={'text'})
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The text describes the preparation of perovskite nanosheets through a series of chemical transformations. The starting material, KCa2Nb3O10, is first converted into a protonic form, HCa2Nb3O10 1.5H2O, using HNO3. This intermediate is then delaminated using tetrabutylammonium hydroxide (TBAOH) to produce Ca2Nb3O10 nanosheets. Additionally, other nanosheets such as Sr2Nb3O10, Ca2Ta3O10, and Sr2Ta3O10 are synthesized by delaminating their respective layered perovskites (KSr2Nb3O10, KCa2Ta3O10, and KSr2Ta3O10). Each step involves a transformation of a precursor into a target product, often with the aid of an additive.
#
# [[ ## reactions ## ]]
# [{"precursors": ["KCa2Nb3O10"], "additives": ["HNO3"], "target": {"target_formula": "HCa2Nb3O10 1.5H2O", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["HCa2Nb3O10 1.5H2O"], "additives": ["TBAOH"], "target": {"target_formula": "Ca2Nb3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["KSr2Nb3O10"], "additives": [], "target": {"target_formula": "Sr2Nb3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["KCa2Ta3O10"], "additives": [], "target": {"target_formula": "Ca2Ta3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}, {"precursors": ["KSr2Ta3O10"], "additives": [], "target": {"target_formula": "Sr2Ta3O10", "amount_var": {}, "element_var": {}}, "reaction_type": "others"}]
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2024-12-12T11:08:41.356125]
#
# System message:
#
# Your input fields are:
# 1. `text` (str): a piece of text which may contains chemical reactions
#
# Your output fields are:
# 1. `reasoning` (str)
# 2. `reactions` (Union[list[Reaction], NoneType]): the reactions extracted from the text, return null if no reaction found
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## text ## ]]
# {text}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## reactions ## ]]
# {reactions}        # note: the value you produce must be pareseable according to the following JSON schema: {"$defs": {"Reaction": {"type": "object", "properties": {"additives": {"type": "array", "items": {"type": "string"}, "title": "Additives"}, "precursors": {"type": "array", "description": "ensure it is a valid chemical formula", "items": {"type": "string"}, "title": "Precursors"}, "reaction_type": {"type": "string", "enum": ["solid-state", "sol-gel", "co-precipitation", "hydrothermal", "flux", "others"], "title": "Reaction Type"}, "target": {"$ref": "#/$defs/Target"}}, "required": ["precursors", "additives", "target", "reaction_type"], "title": "Reaction"}, "Target": {"type": "object", "properties": {"amount_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "number"}}, "description": "the amount variable in the formula, e.g. AxBC, {x: [1, 2]}", "title": "Amount Var"}, "element_var": {"type": "object", "additionalProperties": {"type": "array", "items": {"type": "string"}}, "description": "the element variable in the formula", "title": "Element Var"}, "target_formula": {"type": "string", "description": "make sure it is a valid chemical formula", "title": "Target Formula"}}, "required": ["target_formula", "amount_var", "element_var"], "title": "Target"}}, "anyOf": [{"type": "array", "items": {"$ref": "#/$defs/Reaction"}}, {"type": "null"}]}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Identify and extract all chemical reactions from the text. For each reaction:
#
#         Include reactions where precursors and target products are explicitly mentioned.
#         Ensure not to overlook reactions that are less prominently discussed but still have their precursors and target explicitly stated.
#         Also extract intermediate reactions and label them as such.
#
#
# User message:
#
# [[ ## text ## ]]
# Example({'text': 'Perovskite nanosheets were prepared by delaminating layered perovskites according to previously described procedures. The starting material KCa2Nb3O10, prepared by a solid-state reaction, was converted into a protonic form, HCa2Nb3O10 1.5H2O, in HNO3 solution. A colloidal suspension of Ca2Nb3O10 nanosheets was synthesized by delaminating HCa2Nb3O10 1.5H2O, with tetrabutylammonium hydroxide solution (TBAOH). Sr2Nb3O10, Ca2Ta3O10, and Sr2Ta3O10 nanosheets were also synthesized by delaminating layered perovskites (KSr2Nb3O10, KCa2Ta3O10, and KSr2Ta3O10).', 'reactions': [Reaction(precursors=['KCa2Nb3O10'], additives=['HNO3'], target=Target(target_formula='HCa2Nb3O10 1.5H2O', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['HCa2Nb3O10 1.5H2O'], additives=['TBAOH'], target=Target(target_formula='Ca2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Nb3O10'], additives=[], target=Target(target_formula='Sr2Nb3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KCa2Ta3O10'], additives=[], target=Target(target_formula='Ca2Ta3O10', amount_var={}, element_var={}), reaction_type='others'), Reaction(precursors=['KSr2Ta3O10'], additives=[], target=Target(target_formula='Sr2Ta3O10', amount_var={}, element_var={}), reaction_type='others')]}) (input_keys={'text'})
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## reactions ## ]]` (must be formatted as a valid Python Union[list[Reaction], NoneType]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The text describes the preparation of perovskite nanosheets through a series of chemical reactions. The reactions involve the conversion of layered perovskites into their protonic forms and subsequent delamination to form nanosheets. The text explicitly mentions the starting materials, additives, and target products for each reaction, allowing for the extraction of detailed reaction information. The reactions are not categorized under typical reaction types like solid-state or sol-gel, so they are labeled as "others."
#
# [[ ## reactions ## ]]
# [
#     {
#         "precursors": ["KCa2Nb3O10"],
#         "additives": ["HNO3"],
#         "target": {
#             "target_formula": "HCa2Nb3O10 1.5H2O",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "others"
#     },
#     {
#         "precursors": ["HCa2Nb3O10 1.5H2O"],
#         "additives": ["TBAOH"],
#         "target": {
#             "target_formula": "Ca2Nb3O10",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "others"
#     },
#     {
#         "precursors": ["KSr2Nb3O10"],
#         "additives": [],
#         "target": {
#             "target_formula": "Sr2Nb3O10",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "others"
#     },
#     {
#         "precursors": ["KCa2Ta3O10"],
#         "additives": [],
#         "target": {
#             "target_formula": "Ca2Ta3O10",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "others"
#     },
#     {
#         "precursors": ["KSr2Ta3O10"],
#         "additives": [],
#         "target": {
#             "target_formula": "Sr2Ta3O10",
#             "amount_var": {},
#             "element_var": {}
#         },
#         "reaction_type": "others"
#     }
# ]
#
# [[ ## completed ## ]]

# %%
bad_behaviour_dois = [
    "10.1002/adfm.201101123",
    "10.1039/c1cy00199j",
    "10.1016/j.jpcs.2005.02.003"
]
